# %%
import pandas as pd
import torch
from torch_geometric.data import InMemoryDataset
import numpy as np

# %%
df = pd.read_csv(r'../dataset/Next_Generation_Simulation__NGSIM__Vehicle_Trajectories_and_Supporting_Data.csv')

# %%
df_us_101 = df[df["Location"] == "us-101"].drop_duplicates()

# %%
df_us_101 = df_us_101.sort_values(by=['Global_Time'])

# %%
df_us_101 = df_us_101[["Vehicle_ID", "Frame_ID", "Local_X", "Local_Y", "v_Vel", "Following", "Global_Time"]]

# %%
df_us_101['Following'] = df_us_101['Following'] + 1
df_us_101['Vehicle_ID'] = df_us_101['Vehicle_ID'] + 1

# %%
global_times = sorted(set(list(df_us_101['Global_Time'])))
time_len = len(global_times)

time1 = global_times[int(time_len/3 - 600)]
time2 = global_times[int(time_len/3 * 2 + 300)]

# %%
# seperate the dataset to three subsets, the dataset is generated from three videos, each video is 15 minutes
df_1 = df_us_101[df_us_101['Global_Time'] < time1]
df_2 = df_us_101[df_us_101['Global_Time'] > time1]
df_2 = df_2[df_2['Global_Time'] < time2]
df_3 = df_us_101[df_us_101['Global_Time'] > time2]

# get vehicle IDs

# %%
sorted(set(list(df_us_101['Vehicle_ID'])))
print(0)

# %%
frames = get_frames(df_1)

# %%
v_list = get_vehicle_IDs(df_1)
v_list
# Out:
# [3,
#  5,
#  6,
#  7,
#  9,
#  10,
#  11,
#  13,
#  14,
#  15,
#  19,
#  21,
#  22,
#  23,
#  24,
#  26,
#  27,
#  28,
#  32,
#  33,
#  34,
#  35,
#  36,
#  38,
#  40,
#  41,
#  43,
#  44,
#  45,
#  48,
#  49,
#  50,
#  52,
#  54,
#  55,
#  56,
#  57,
#  58,
#  60,
#  61,
#  63,
#  64,
#  65,
#  68,
#  70,
#  72,
#  73,
#  74,
#  75,
#  76,
#  77,
#  78,
#  79,
#  80,
#  83,
#  84,
#  85,
#  91,
#  92,
#  95,
#  96,
#  97,
#  98,
#  100,
#  101,
#  105,
#  106,
#  110,
#  115,
#  116,
#  117,
#  118,
#  119,
#  120,
#  121,
#  122,
#  123,
#  125,
#  126,
#  128,
#  129,
#  132,
#  133,
#  135,
#  136,
#  137,
#  138,
#  140,
#  141,
#  142,
#  143,
#  145,
#  146,
#  147,
#  148,
#  151,
#  152,
#  153,
#  154,
#  158,
#  159,
#  160,
#  162,
#  163,
#  164,
#  165,
#  168,
#  170,
#  171,
#  175,
#  176,
#  177,
#  180,
#  181,
#  182,
#  183,
#  184,
#  185,
#  191,
#  192,
#  193,
#  195,
#  197,
#  199,
#  200,
#  201,
#  204,
#  205,
#  206,
#  207,
#  213,
#  214,
#  215,
#  216,
#  217,
#  218,
#  220,
#  221,
#  222,
#  224,
#  225,
#  226,
#  227,
#  228,
#  229,
#  231,
#  232,
#  233,
#  234,
#  235,
#  238,
#  240,
#  241,
#  242,
#  243,
#  246,
#  247,
#  248,
#  250,
#  251,
#  253,
#  254,
#  255,
#  256,
#  258,
#  272,
#  273,
#  278,
#  279,
#  280,
#  281,
#  282,
#  283,
#  285,
#  286,
#  290,
#  291,
#  293,
#  296,
#  297,
#  298,
#  299,
#  301,
#  302,
#  303,
#  305,
#  306,
#  307,
#  309,
#  310,
#  311,
#  312,
#  320,
#  321,
#  322,
#  323,
#  324,
#  325,
#  329,
#  330,
#  331,
#  332,
#  333,
#  340,
#  341,
#  343,
#  345,
#  346,
#  347,
#  348,
#  351,
#  352,
#  353,
#  357,
#  358,
#  359,
#  364,
#  365,
#  366,
#  367,
#  368,
#  369,
#  373,
#  374,
#  375,
#  376,
#  377,
#  380,
#  381,
#  382,
#  384,
#  385,
#  388,
#  389,
#  390,
#  394,
#  395,
#  396,
#  397,
#  398,
#  400,
#  401,
#  402,
#  403,
#  404,
#  405,
#  406,
#  408,
#  409,
#  411,
#  412,
#  416,
#  417,
#  418,
#  419,
#  420,
#  423,
#  424,
#  425,
#  427,
#  428,
#  432,
#  434,
#  435,
#  436,
#  437,
#  439,
#  440,
#  441,
#  442,
#  443,
#  444,
#  446,
#  447,
#  448,
#  450,
#  451,
#  452,
#  453,
#  457,
#  458,
#  459,
#  463,
#  465,
#  466,
#  468,
#  469,
#  470,
#  473,
#  474,
#  476,
#  477,
#  478,
#  482,
#  483,
#  484,
#  485,
#  486,
#  487,
#  489,
#  490,
#  492,
#  493,
#  494,
#  495,
#  496,
#  497,
#  501,
#  502,
#  503,
#  504,
#  505,
#  507,
#  508,
#  513,
#  514,
#  515,
#  516,
#  519,
#  521,
#  523,
#  524,
#  525,
#  526,
#  527,
#  528,
#  530,
#  532,
#  534,
#  543,
#  544,
#  545,
#  546,
#  547,
#  550,
#  551,
#  555,
#  556,
#  558,
#  559,
#  561,
#  562,
#  563,
#  564,
#  565,
#  566,
#  567,
#  568,
#  571,
#  572,
#  578,
#  579,
#  580,
#  582,
#  583,
#  584,
#  586,
#  587,
#  588,
#  589,
#  590,
#  591,
#  594,
#  596,
#  597,
#  598,
#  599,
#  602,
#  603,
#  604,
#  606,
#  611,
#  612,
#  613,
#  616,
#  617,
#  618,
#  619,
#  620,
#  623,
#  624,
#  625,
#  630,
#  631,
#  632,
#  633,
#  634,
#  636,
#  637,
#  640,
#  642,
#  644,
#  646,
#  647,
#  649,
#  650,
#  651,
#  653,
#  654,
#  657,
#  659,
#  660,
#  661,
#  662,
#  666,
#  668,
#  669,
#  670,
#  672,
#  673,
#  675,
#  676,
#  677,
#  680,
#  681,
#  682,
#  683,
#  684,
#  687,
#  688,
#  690,
#  691,
#  692,
#  693,
#  695,
#  696,
#  698,
#  699,
#  700,
#  702,
#  703,
#  704,
#  705,
#  706,
#  707,
#  710,
#  711,
#  712,
#  713,
#  715,
#  716,
#  718,
#  720,
#  725,
#  726,
#  727,
#  728,
#  729,
#  730,
#  731,
#  733,
#  734,
#  735,
#  736,
#  737,
#  738,
#  739,
#  740,
#  741,
#  742,
#  743,
#  749,
#  750,
#  751,
#  752,
#  753,
#  754,
#  756,
#  757,
#  759,
#  760,
#  762,
#  763,
#  764,
#  766,
#  768,
#  769,
#  770,
#  772,
#  774,
#  775,
#  776,
#  777,
#  779,
#  780,
#  781,
#  782,
#  783,
#  785,
#  786,
#  787,
#  788,
#  789,
#  791,
#  792,
#  793,
#  794,
#  797,
#  799,
#  800,
#  801,
#  802,
#  807,
#  809,
#  810,
#  811,
#  812,
#  813,
#  814,
#  817,
#  818,
#  819,
#  822,
#  823,
#  824,
#  826,
#  827,
#  828,
#  832,
#  833,
#  834,
#  835,
#  836,
#  837,
#  838,
#  840,
#  844,
#  845,
#  846,
#  847,
#  850,
#  851,
#  852,
#  853,
#  855,
#  859,
#  860,
#  861,
#  862,
#  866,
#  867,
#  868,
#  870,
#  872,
#  873,
#  874,
#  875,
#  877,
#  880,
#  881,
#  883,
#  884,
#  886,
#  887,
#  888,
#  889,
#  890,
#  891,
#  892,
#  893,
#  897,
#  898,
#  899,
#  902,
#  904,
#  905,
#  906,
#  907,
#  909,
#  910,
#  912,
#  913,
#  914,
#  916,
#  917,
#  918,
#  919,
#  924,
#  925,
#  926,
#  928,
#  929,
#  930,
#  932,
#  933,
#  934,
#  937,
#  943,
#  944,
#  945,
#  946,
#  947,
#  948,
#  949,
#  950,
#  951,
#  953,
#  954,
#  955,
#  956,
#  957,
#  958,
#  959,
#  960,
#  962,
#  963,
#  965,
#  966,
#  967,
#  968,
#  969,
#  970,
#  971,
#  972,
#  973,
#  974,
#  975,
#  976,
#  977,
#  978,
#  979,
#  980,
#  981,
#  982,
#  983,
#  984,
#  987,
#  988,
#  990,
#  991,
#  992,
#  993,
#  997,
#  998,
#  999,
#  1001,
#  1002,
#  1003,
#  1004,
#  1006,
#  1007,
#  1008,
#  1009,
#  1010,
#  1011,
#  1012,
#  1013,
#  1014,
#  1015,
#  1017,
#  1022,
#  1023,
#  1024,
#  1025,
#  1026,
#  1027,
#  1028,
#  1029,
#  1030,
#  1031,
#  1032,
#  1033,
#  1034,
#  1036,
#  1037,
#  1038,
#  1039,
#  1040,
#  1041,
#  1042,
#  1043,
#  1044,
#  1045,
#  1046,
#  1047,
#  1048,
#  1050,
#  1051,
#  1052,
#  1053,
#  1054,
#  1055,
#  1056,
#  1057,
#  1058,
#  1059,
#  1060,
#  1061,
#  1062,
#  1063,
#  1064,
#  1065,
#  1066,
#  1067,
#  1068,
#  1069,
#  1070,
#  1071,
#  1072,
#  1073,
#  1074,
#  1075,
#  1076,
#  1077,
#  1078,
#  1079,
#  1080,
#  1081,
#  1082,
#  1083,
#  1084,
#  1085,
#  1087,
#  1088,
#  1089,
#  1090,
#  1091,
#  1092,
#  1093,
#  1094,
#  1095,
#  1096,
#  1097,
#  1098,
#  1099,
#  1100,
#  1101,
#  1102,
#  1103,
#  1104,
#  1105,
#  1106,
#  1107,
#  1108,
#  1109,
#  1110,
#  1111,
#  1112,
#  1113,
#  1114,
#  1115,
#  1116,
#  1117,
#  1119,
#  1120,
#  1121,
#  1122,
#  1123,
#  1124,
#  1125,
#  1126,
#  1127,
#  1128,
#  1129,
#  1130,
#  1131,
#  1132,
#  1133,
#  1134,
#  1135,
#  1136,
#  1137,
#  1138,
#  1139,
#  1144,
#  1145,
#  1146,
#  1147,
#  1148,
#  1149,
#  1150,
#  1151,
#  1153,
#  1154,
#  1155,
#  1156,
#  1157,
#  1158,
#  1159,
#  1160,
#  1161,
#  1162,
#  1163,
#  1164,
#  1165,
#  1166,
#  1167,
#  1168,
#  1169,
#  1170,
#  1171,
#  1172,
#  1173,
#  1174,
#  1175,
#  1176,
#  1177,
#  1178,
#  1179,
#  1180,
#  1181,
#  1182,
#  1183,
#  1184,
#  1186,
#  1187,
#  1188,
#  1189,
#  1190,
#  1191,
#  1192,
#  1193,
#  1195,
#  1196,
#  1197,
#  1198,
#  1199,
#  1200,
#  1201,
#  1202,
#  1203,
#  1204,
#  1205,
#  1206,
#  1207,
#  1208,
#  1209,
#  1210,
#  1211,
#  1212,
#  1213,
#  1214,
#  1215,
#  1216,
#  1217,
#  1218,
#  1219,
#  1220,
#  1221,
#  1222,
#  1224,
#  1225,
#  1226,
#  1227,
#  1228,
#  1229,
#  1230,
#  1231,
#  1232,
#  1233,
#  1234,
#  1235,
#  1236,
#  1237,
#  1238,
#  1239,
#  1240,
#  1241,
#  1242,
#  1243,
#  1244,
#  1245,
#  1246,
#  1247,
#  1248,
#  1249,
#  1250,
#  1251,
#  1252,
#  1253,
#  1254,
#  1255,
#  1256,
#  1257,
#  1258,
#  1259,
#  1260,
#  1261,
#  1262,
#  1263,
#  1268,
#  1270,
#  1272,
#  1273,
#  1274,
#  1275,
#  1276,
#  1277,
#  1278,
#  1279,
#  1280,
#  1281,
#  1283,
#  1284,
#  1285,
#  1286,
#  1287,
#  1288,
#  1289,
#  1290,
#  1291,
#  1292,
#  1293,
#  1295,
#  1297,
#  1301,
#  1302,
#  1303,
#  1305,
#  1310,
#  1312,
#  1314,
#  1315,
#  1316,
#  1318,
#  1322,
#  1324,
#  1326,
#  1328,
#  1329,
#  1333,
#  1334,
#  1335,
#  1336,
#  1337,
#  1338,
#  1339,
#  1340,
#  1343,
#  1344,
#  1345,
#  1347,
#  1348,
#  1349,
#  1350,
#  1351,
#  1352,
#  1353,
#  1354,
#  1355,
#  1359,
#  1360,
#  1361,
#  1362,
#  1363,
#  1364,
#  1365,
#  1366,
#  1367,
#  1368,
#  1369,
#  1370,
#  1371,
#  1372,
#  1373,
#  1374,
#  1387,
#  1388,
#  1389,
#  1390,
#  1391,
#  1392,
#  1393,
#  1394,
#  1395,
#  1396,
#  1397,
#  1398,
#  1399,
#  1400,
#  1401,
#  1402,
#  1404,
#  1405,
#  1406,
#  1407,
#  1408,
#  1409,
#  1410,
#  1413,
#  1416,
#  1417,
#  1418,
#  1420,
#  1421,
#  1424,
#  1425,
#  1426,
#  1428,
#  1429,
#  1430,
#  1431,
#  1432,
#  1433,
#  1436,
#  1437,
#  1439,
#  1441,
#  1442,
#  1443,
#  ...]

# %%
V = 11
frames_list = sorted(set(list(df_1[df_1['Vehicle_ID'] == V]['Frame_ID'])))

# %%
frame_ID = frames_list[0:30]
ID = frame_ID[10]
frames[ID]
# Out:
#          Vehicle_ID  Frame_ID  Local_X  Local_Y  v_Vel  Following  \
# 8293612          15        49   49.163  116.893  40.00         19
# 2286149          14        49   16.328  132.082  34.63         23
# 4823539           3        49   15.226  172.044  39.18         14
# 7041614          23        49   14.907   71.945  30.00          1
# 8486301          19        49   51.134   49.644  35.00          1
# 4918918          11        49    4.099   76.932  39.93          1
# 4812760          10        49   27.335   58.493  39.98          1
# 1082265           9        49   37.025  127.856  44.94          1
# 8312950           6        49   38.824  192.985  36.09          9
#
#            Global_Time
# 8293612  1118846983800
# 2286149  1118846983800
# 4823539  1118846983800
# 7041614  1118846983800
# 8486301  1118846983800
# 4918918  1118846983800
# 4812760  1118846983800
# 1082265  1118846983800
# 8312950  1118846983800

# %%
frame = frames[ID].copy()
frame_y = []
y = frame[frame['Vehicle_ID'] == V][['Local_X', 'Local_Y', 'v_Vel']].values
frame_y.append(y.tolist()[0])
print(frame_y)

frame['Vehicle_ID'] = frame['Vehicle_ID'].replace(V, 1)
frame['Following'] = frame['Following'].replace(1, 0)
frame['Following'] = frame['Following'].replace(V, 1)
frame = frame.sort_values(by=["Vehicle_ID"])
frame['v_index'] = range(len(frame.index))

frame_edge = frame[frame['Following'] != 0]
edge_from = list(frame_edge['v_index'])
edge_to_origin = list(frame_edge['Following'])
edge_to = []
vehicles_id = list(frame['Vehicle_ID'])
for to_origin in edge_to_origin:
    new_v_index = vehicles_id.index(to_origin)
    edge_to.append(new_v_index)
frame_x = torch.tensor(frame[['Local_X', 'Local_Y', 'v_Vel']].values)
frame_edge = torch.tensor([edge_from, edge_to], dtype=torch.long)
y = []
data = Data(x=frame_x, y=y, edge_index=frame_edge)
# Out:
# [[4.099, 76.932, 39.93]]

# %%
frame = frames[ID]
frame_y = frame[frame['Vehicle_ID'] == V][['Local_X', 'Local_Y', 'v_Vel']].values
print(frame_y)
# Out:
# []

# %%
frame[['Local_X', 'Local_Y', 'v_Vel']]
# Out:
#          Local_X  Local_Y  v_Vel
# 479094    27.422   41.492  39.98
# 3823419   16.376  156.449  38.76
# 3275924   40.072  178.551  35.80
# 4274370   36.807  109.841  45.00
# 8276503    4.182   60.953  40.28
# 8561326   16.158  118.065  35.00
# 5105977   48.968  100.845  39.54
# 8533566   14.968   59.947  29.97

# %%
print(edge_from)
print(edge_to)
# Out:
# [1, 2, 5]
# [5, 3, 7]

# %%
# get vehicle IDs
def get_vehicle_IDs(df):
    vehicles = sorted(set(list(df["Vehicle_ID"])))
    return vehicles

# get frame list, frame = frame_list[frame_index_in_df]
def get_frames(df):
    frames = sorted(set(list(df["Frame_ID"])))
    frames_list = [0] * (frames[-1]+1)
    for frame_index in frames:
        frame = df[df["Frame_ID"] == frame_index]
        frames_list[frame_index] = frame
    return frames_list

def get_x_y(frames, frame_list, V):
    x_list = []
    frame_y = []
    for f in frames[0:20]:
        frame = frame_list[f].copy()
        frame['Vehicle_ID'] = frame['Vehicle_ID'].replace(V, 1)
        frame['Following'] = frame['Following'].replace(1, 0)
        frame['Following'] = frame['Following'].replace(V, 1)
        frame = frame.sort_values(by=["Vehicle_ID"])
        frame['v_index'] = range(len(frame.index))

        frame_edge = frame[frame['Following'] != 0]
        edge_from = list(frame_edge['v_index'])
        edge_to_origin = list(frame_edge['Following'])
        edge_to = []
        vehicles_id = list(frame['Vehicle_ID'])
        for to_origin in edge_to_origin:
            new_v_index = vehicles_id.index(to_origin)
            edge_to.append(new_v_index)
        frame_x = torch.tensor(frame[['Local_X', 'Local_Y', 'v_Vel']].values)
        frame_edge = torch.tensor([edge_from, edge_to], dtype=torch.long)
        y = []
        data = Data(x=frame_x, y=y, edge_index=frame_edge)
        x_list.append(data)
    for f in frames[20:]:
        frame = frame_list[f]
        y = frame[frame['Vehicle_ID'] == V][['Local_X', 'Local_Y', 'v_Vel']].values
        frame_y.append(y.tolist()[0])
    y_list = torch.FloatTensor(frame_y)
    return x_list, y_list

# %%
def prepare_dataset(df):
    data_x_list = []
    data_y_list = []
    # get vehicle IDs
    V_IDs = get_vehicle_IDs(df)
    print(V_IDs[-1])
    # get frame list:
    frame_list = get_frames(df)
    
    for V in V_IDs:
        print(V)
        frames = sorted(set(list(df[df['Vehicle_ID'] == V]['Frame_ID'])))
        frames_len = len(frames)
        if frames_len < 90:
            continue
        else:
            f_1 = frames[0:30]
            f_2 = frames[int(frames_len/3): int(frames_len/3) + 30]
            f_3 = frames[int(frames_len/3) * 2: int(frames_len/3) * 2 + 30]
            data_x, data_y = get_x_y(f_1, frame_list, V)
#             data_list.append([data_x, data_y])
            data_x_list.append(data_x)
            data_y_list.append(data_y)    
        
            data_x, data_y = get_x_y(f_2, frame_list, V)
#             data_list.append([data_x, data_y])
            data_x_list.append(data_x)
            data_y_list.append(data_y) 
        
            data_x, data_y = get_x_y(f_3, frame_list, V)
            data_x_list.append(data_x)
            data_y_list.append(data_y)
            
            
    return [data_x_list, data_y_list]

# %%
dataset = prepare_dataset(df_1)
# Out:
# 3110
# 3
# 5
# 6
# 7
# 9
# 10
# 11
# 13
# 14
# 15
# 19
# 21
# 22
# 23
# 24
# 26
# 27
# 28
#
# 2859
# 2860
# 2861
# 2862
# 2863
# 2864
# 2865
# 2866
# 2869
# 2870
# 2871
# 2872
# 2873
# 2874
# 2875
# 2876
# 2877
# 2878
# 2879
# 2880
# 2881
# 2882
# 2887
# 2892
# 2893
# 2895
# 2896
# 2897
# 2899
# 2900
# 2901
# 2902
# 2904
# 2907
# 2908
# 2911
# 2912
# 2913
# 2914
# 2916
# 2917
# 2919
# 2922
# 2923
# 2924
# 2925
# 2926
# 2927
# 2929
# 2931
# 2932
# 2933
# 2939
# 2940
# 2941
# 2942
# 2943
# 2944
# 2946
# 2947
# 2949
# 2951
# 2954
# 2955
# 2957
# 2959
# 2960
# 2962
# 2963
# 2965
# 2968
# 2970
# 2972
# 2973
# 2974
# 2975
# 2978
# 2979
# 2980
# 2983
# 2984
# 2985
# 2989
# 2992
# 2993
# 2994
# 2997
# 3008
# 3012
# 3102
# 3103
# 3104
# 3105
# 3106
# 3107
# 3108
# 3109
# 3110

# %%
frames = sorted(set(list(df_3["Frame_ID"])))

# %%
len(frames)
# Out:
# 8574

# %%
V = 2, frames

# %%
df_3[df_3['Vehicle_ID'] == 1000].sort_values(by=['Frame_ID'])
# Out:
#          Vehicle_ID  Frame_ID  Total_Frames    Global_Time  Local_X   Local_Y  \
# 196096         1000      4602           936  1118849217200    4.184    69.166
# 7351338        1000      4603           936  1118849217300    4.179    70.166
# 1883672        1000      4604           936  1118849217400    4.174    71.167
# 7464919        1000      4605           936  1118849217500    4.168    72.166
# 6877370        1000      4606           936  1118849217600    4.163    73.166
# ...             ...       ...           ...            ...      ...       ...
# 4805862        1000      5533           936  1118849310300    8.684  2146.667
# 4435588        1000      5534           936  1118849310400    8.682  2150.498
# 2005627        1000      5535           936  1118849310500    8.679  2154.352
# 3683384        1000      5536           936  1118849310600    8.676  2158.352
# 6029912        1000      5537           936  1118849310700    8.672  2162.352
#
#             Global_X     Global_Y  v_length  v_Width  ...  D_Zone  Int_ID  \
# 196096   6451146.121  1873353.901      15.0      6.4  ...     NaN     NaN
# 7351338  6451146.793  1873353.161      15.0      6.4  ...     NaN     NaN
# 1883672  6451147.466  1873352.420      15.0      6.4  ...     NaN     NaN
# 7464919  6451148.138  1873351.680      15.0      6.4  ...     NaN     NaN
# 6877370  6451148.810  1873350.940      15.0      6.4  ...     NaN     NaN
# ...              ...          ...       ...      ...  ...     ...     ...
# 4805862  6452690.192  1871964.429      15.0      6.4  ...     NaN     NaN
# 4435588  6452693.189  1871962.043      15.0      6.4  ...     NaN     NaN
# 2005627  6452696.201  1871959.646      15.0      6.4  ...     NaN     NaN
# 3683384  6452699.331  1871957.155      15.0      6.4  ...     NaN     NaN
# 6029912  6452702.461  1871954.665      15.0      6.4  ...     NaN     NaN
#
#          Section_ID  Direction  Movement  Preceding  Following  Space_Headway  \
# 196096          NaN        NaN       NaN        994          0          36.55
# 7351338         NaN        NaN       NaN        994          0          36.55
# 1883672         NaN        NaN       NaN        994          0          36.56
# 7464919         NaN        NaN       NaN        994          0          36.57
# 6877370         NaN        NaN       NaN        994          0          36.58
# ...             ...        ...       ...        ...        ...            ...
# 4805862         NaN        NaN       NaN          0       1005           0.00
# 4435588         NaN        NaN       NaN          0       1005           0.00
# 2005627         NaN        NaN       NaN          0       1005           0.00
# 3683384         NaN        NaN       NaN          0       1005           0.00
# 6029912         NaN        NaN       NaN          0       1005           0.00
#
#          Time_Headway  Location
# 196096           3.26    us-101
# 7351338          3.26    us-101
# 1883672          3.26    us-101
# 7464919          3.26    us-101
# 6877370          3.26    us-101
# ...               ...       ...
# 4805862          0.00    us-101
# 4435588          0.00    us-101
# 2005627          0.00    us-101
# 3683384          0.00    us-101
# 6029912          0.00    us-101
#
# [936 rows x 25 columns]

# %%
df_us_101[df_us_101['Vehicle_ID'] == 1].sort_values(by=['Frame_ID'])
# Out:
#          Vehicle_ID  Frame_ID  Total_Frames    Global_Time  Local_X   Local_Y  \
# 2555981           1       137           421  1118848770700   52.660    73.916
# 7952522           1       138           421  1118848770800   52.648    76.416
# 7911821           1       139           421  1118848770900   52.635    78.915
# 7890998           1       140           421  1118848771000   52.622    81.416
# 7289640           1       141           421  1118848771100   52.609    83.916
# ...             ...       ...           ...            ...      ...       ...
# 4787305           1       834           569  1118847925400   56.965  2143.216
# 3147654           1       835           569  1118847925500   56.946  2149.061
# 6083260           1       836           569  1118847925600   56.942  2154.789
# 4265363           1       837           569  1118847925700   56.937  2160.789
# 8483966           1       838           569  1118847925800   56.932  2166.789
#
#             Global_X     Global_Y  v_length  v_Width  ...  D_Zone  Int_ID  \
# 2555981  6451113.236  1873317.970      15.0      6.4  ...     NaN     NaN
# 7952522  6451114.916  1873316.119      15.0      6.4  ...     NaN     NaN
# 7911821  6451116.596  1873314.268      15.0      6.4  ...     NaN     NaN
# 7890998  6451118.277  1873312.417      15.0      6.4  ...     NaN     NaN
# 7289640  6451119.957  1873310.566      15.0      6.4  ...     NaN     NaN
# ...              ...          ...       ...      ...  ...     ...     ...
# 4787305  6452653.129  1871932.226      47.0      8.5  ...     NaN     NaN
# 3147654  6452657.733  1871928.584      47.0      8.5  ...     NaN     NaN
# 6083260  6452662.154  1871925.065      47.0      8.5  ...     NaN     NaN
# 4265363  6452666.849  1871921.329      47.0      8.5  ...     NaN     NaN
# 8483966  6452671.544  1871917.593      47.0      8.5  ...     NaN     NaN
#
#          Section_ID  Direction  Movement  Preceding  Following  Space_Headway  \
# 2555981         NaN        NaN       NaN          0          0            0.0
# 7952522         NaN        NaN       NaN          0          0            0.0
# 7911821         NaN        NaN       NaN          0          0            0.0
# 7890998         NaN        NaN       NaN          0          0            0.0
# 7289640         NaN        NaN       NaN          0          0            0.0
# ...             ...        ...       ...        ...        ...            ...
# 4787305         NaN        NaN       NaN          0         16            0.0
# 3147654         NaN        NaN       NaN          0         16            0.0
# 6083260         NaN        NaN       NaN          0         16            0.0
# 4265363         NaN        NaN       NaN          0         16            0.0
# 8483966         NaN        NaN       NaN          0         16            0.0
#
#          Time_Headway  Location
# 2555981           0.0    us-101
# 7952522           0.0    us-101
# 7911821           0.0    us-101
# 7890998           0.0    us-101
# 7289640           0.0    us-101
# ...               ...       ...
# 4787305           0.0    us-101
# 3147654           0.0    us-101
# 6083260           0.0    us-101
# 4265363           0.0    us-101
# 8483966           0.0    us-101
#
# [990 rows x 25 columns]

# %%
times = list(df_us_101["Global_Time"])
vehicles = list(df_us_101["Vehicle_ID"])

# %%
df_len = len(df_us_101.index)
df_len
# Out:
# 4098933

# %%
times = set(times)
vehicles = set(vehicles)

# %%
times = sorted(times)
vehicles = sorted(vehicles)

# %%
len(times)
# Out:
# 27726

# %%
len(vehicles)
# Out:
# 2847

# %%
v = df_us_101[df_us_101["Vehicle_ID"] == vehicles[0]].sort_values(by=['Frame_ID'])

# %%
v
# Out:
#          Vehicle_ID  Frame_ID  Total_Frames    Global_Time  Local_X   Local_Y  \
# 2555981           1       137           421  1118848770700   52.660    73.916
# 7952522           1       138           421  1118848770800   52.648    76.416
# 7911821           1       139           421  1118848770900   52.635    78.915
# 7890998           1       140           421  1118848771000   52.622    81.416
# 7289640           1       141           421  1118848771100   52.609    83.916
# ...             ...       ...           ...            ...      ...       ...
# 4787305           1       834           569  1118847925400   56.965  2143.216
# 3147654           1       835           569  1118847925500   56.946  2149.061
# 6083260           1       836           569  1118847925600   56.942  2154.789
# 4265363           1       837           569  1118847925700   56.937  2160.789
# 8483966           1       838           569  1118847925800   56.932  2166.789
#
#             Global_X     Global_Y  v_length  v_Width  ...  D_Zone  Int_ID  \
# 2555981  6451113.236  1873317.970      15.0      6.4  ...     NaN     NaN
# 7952522  6451114.916  1873316.119      15.0      6.4  ...     NaN     NaN
# 7911821  6451116.596  1873314.268      15.0      6.4  ...     NaN     NaN
# 7890998  6451118.277  1873312.417      15.0      6.4  ...     NaN     NaN
# 7289640  6451119.957  1873310.566      15.0      6.4  ...     NaN     NaN
# ...              ...          ...       ...      ...  ...     ...     ...
# 4787305  6452653.129  1871932.226      47.0      8.5  ...     NaN     NaN
# 3147654  6452657.733  1871928.584      47.0      8.5  ...     NaN     NaN
# 6083260  6452662.154  1871925.065      47.0      8.5  ...     NaN     NaN
# 4265363  6452666.849  1871921.329      47.0      8.5  ...     NaN     NaN
# 8483966  6452671.544  1871917.593      47.0      8.5  ...     NaN     NaN
#
#          Section_ID  Direction  Movement  Preceding  Following  Space_Headway  \
# 2555981         NaN        NaN       NaN          0          0            0.0
# 7952522         NaN        NaN       NaN          0          0            0.0
# 7911821         NaN        NaN       NaN          0          0            0.0
# 7890998         NaN        NaN       NaN          0          0            0.0
# 7289640         NaN        NaN       NaN          0          0            0.0
# ...             ...        ...       ...        ...        ...            ...
# 4787305         NaN        NaN       NaN          0         16            0.0
# 3147654         NaN        NaN       NaN          0         16            0.0
# 6083260         NaN        NaN       NaN          0         16            0.0
# 4265363         NaN        NaN       NaN          0         16            0.0
# 8483966         NaN        NaN       NaN          0         16            0.0
#
#          Time_Headway  Location
# 2555981           0.0    us-101
# 7952522           0.0    us-101
# 7911821           0.0    us-101
# 7890998           0.0    us-101
# 7289640           0.0    us-101
# ...               ...       ...
# 4787305           0.0    us-101
# 3147654           0.0    us-101
# 6083260           0.0    us-101
# 4265363           0.0    us-101
# 8483966           0.0    us-101
#
# [990 rows x 25 columns]

# %%
dataset_1 = df_us_101
frame_list = [0] * 30000
for i in times:
    vehicles_df1 = df_us_101[df_us_101["Global_Time"] == i]
    frame_list_1.append(vehicles_df)
    
    frame_list_2
    frame_list_3

# %%
len(frame_list)
# Out:
# 27726

# %%
len(list(frame_list[1090]['Vehicle_ID']))
# Out:
# 121

# %%
len(set(frame_list[1090]['Vehicle_ID']))
# Out:
# 121

# %%
import os
import pandas as pd
import numpy as np
import torch
from torch.utils.data import Dataset, DataLoader

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
from torch.utils.data import Dataset
class NGSIMDataset(Dataset):
    
    def __init__(self, data_list, transform=None):
        self.data = data_list
        self.transform = transform
        self.x_list = data_list[0]
        self.y_list = data_list[1]
        
    def __len__(self):
        return len(self.data[0])
    
    def __getitem__(self, idx):
        if torch.is_tensor(idx):
            idx = idx.tolist()
        x = self.x_list[idx]
        y = self.y_list[idx]
        
        return x, y
        
#         sample = {'graphs': x, 'y': y}
        
#         if self.transform:
#             sample = self.transform(sample)
        
#         return sample

# %%
dataset_a = NGSIMDataset(dataset)

# %%
dataset[0][0]
# Out:
# [Data(x=[3, 3], edge_index=[2, 0], y=[0]),
#  Data(x=[3, 3], edge_index=[2, 0], y=[0]),
#  Data(x=[3, 3], edge_index=[2, 0], y=[0]),
#  Data(x=[3, 3], edge_index=[2, 0], y=[0]),
#  Data(x=[3, 3], edge_index=[2, 0], y=[0]),
#  Data(x=[3, 3], edge_index=[2, 0], y=[0]),
#  Data(x=[2, 3], edge_index=[2, 0], y=[0]),
#  Data(x=[2, 3], edge_index=[2, 0], y=[0]),
#  Data(x=[2, 3], edge_index=[2, 0], y=[0]),
#  Data(x=[3, 3], edge_index=[2, 1], y=[0]),
#  Data(x=[3, 3], edge_index=[2, 1], y=[0]),
#  Data(x=[3, 3], edge_index=[2, 1], y=[0]),
#  Data(x=[3, 3], edge_index=[2, 1], y=[0]),
#  Data(x=[3, 3], edge_index=[2, 1], y=[0]),
#  Data(x=[3, 3], edge_index=[2, 1], y=[0]),
#  Data(x=[3, 3], edge_index=[2, 1], y=[0]),
#  Data(x=[4, 3], edge_index=[2, 2], y=[0]),
#  Data(x=[4, 3], edge_index=[2, 2], y=[0]),
#  Data(x=[4, 3], edge_index=[2, 2], y=[0]),
#  Data(x=[5, 3], edge_index=[2, 2], y=[0])]

# %%
from torch_geometric.data import DataLoader

train_dataloader = DataLoader(dataset_a, batch_size=64)

# %%
x1, train_labels = next(iter(train_dataloader))
x1
# Out:
# [DataBatch(x=[3404, 3], edge_index=[2, 3025], y=[64], batch=[3404], ptr=[65]),
#  DataBatch(x=[3419, 3], edge_index=[2, 3041], y=[64], batch=[3419], ptr=[65]),
#  DataBatch(x=[3430, 3], edge_index=[2, 3052], y=[64], batch=[3430], ptr=[65]),
#  DataBatch(x=[3439, 3], edge_index=[2, 3059], y=[64], batch=[3439], ptr=[65]),
#  DataBatch(x=[3450, 3], edge_index=[2, 3070], y=[64], batch=[3450], ptr=[65]),
#  DataBatch(x=[3471, 3], edge_index=[2, 3090], y=[64], batch=[3471], ptr=[65]),
#  DataBatch(x=[3485, 3], edge_index=[2, 3103], y=[64], batch=[3485], ptr=[65]),
#  DataBatch(x=[3504, 3], edge_index=[2, 3121], y=[64], batch=[3504], ptr=[65]),
#  DataBatch(x=[3521, 3], edge_index=[2, 3138], y=[64], batch=[3521], ptr=[65]),
#  DataBatch(x=[3539, 3], edge_index=[2, 3154], y=[64], batch=[3539], ptr=[65]),
#  DataBatch(x=[3550, 3], edge_index=[2, 3165], y=[64], batch=[3550], ptr=[65]),
#  DataBatch(x=[3568, 3], edge_index=[2, 3182], y=[64], batch=[3568], ptr=[65]),
#  DataBatch(x=[3582, 3], edge_index=[2, 3193], y=[64], batch=[3582], ptr=[65]),
#  DataBatch(x=[3608, 3], edge_index=[2, 3216], y=[64], batch=[3608], ptr=[65]),
#  DataBatch(x=[3620, 3], edge_index=[2, 3230], y=[64], batch=[3620], ptr=[65]),
#  DataBatch(x=[3637, 3], edge_index=[2, 3246], y=[64], batch=[3637], ptr=[65]),
#  DataBatch(x=[3650, 3], edge_index=[2, 3258], y=[64], batch=[3650], ptr=[65]),
#  DataBatch(x=[3665, 3], edge_index=[2, 3270], y=[64], batch=[3665], ptr=[65]),
#  DataBatch(x=[3680, 3], edge_index=[2, 3284], y=[64], batch=[3680], ptr=[65]),
#  DataBatch(x=[3696, 3], edge_index=[2, 3298], y=[64], batch=[3696], ptr=[65])]

# %%
x1, train_labels = next(iter(train_dataloader))
x1
# Out:
# [DataBatch(x=[3404, 3], edge_index=[2, 3025], y=[64], batch=[3404], ptr=[65]),
#  DataBatch(x=[3419, 3], edge_index=[2, 3041], y=[64], batch=[3419], ptr=[65]),
#  DataBatch(x=[3430, 3], edge_index=[2, 3052], y=[64], batch=[3430], ptr=[65]),
#  DataBatch(x=[3439, 3], edge_index=[2, 3059], y=[64], batch=[3439], ptr=[65]),
#  DataBatch(x=[3450, 3], edge_index=[2, 3070], y=[64], batch=[3450], ptr=[65]),
#  DataBatch(x=[3471, 3], edge_index=[2, 3090], y=[64], batch=[3471], ptr=[65]),
#  DataBatch(x=[3485, 3], edge_index=[2, 3103], y=[64], batch=[3485], ptr=[65]),
#  DataBatch(x=[3504, 3], edge_index=[2, 3121], y=[64], batch=[3504], ptr=[65]),
#  DataBatch(x=[3521, 3], edge_index=[2, 3138], y=[64], batch=[3521], ptr=[65]),
#  DataBatch(x=[3539, 3], edge_index=[2, 3154], y=[64], batch=[3539], ptr=[65]),
#  DataBatch(x=[3550, 3], edge_index=[2, 3165], y=[64], batch=[3550], ptr=[65]),
#  DataBatch(x=[3568, 3], edge_index=[2, 3182], y=[64], batch=[3568], ptr=[65]),
#  DataBatch(x=[3582, 3], edge_index=[2, 3193], y=[64], batch=[3582], ptr=[65]),
#  DataBatch(x=[3608, 3], edge_index=[2, 3216], y=[64], batch=[3608], ptr=[65]),
#  DataBatch(x=[3620, 3], edge_index=[2, 3230], y=[64], batch=[3620], ptr=[65]),
#  DataBatch(x=[3637, 3], edge_index=[2, 3246], y=[64], batch=[3637], ptr=[65]),
#  DataBatch(x=[3650, 3], edge_index=[2, 3258], y=[64], batch=[3650], ptr=[65]),
#  DataBatch(x=[3665, 3], edge_index=[2, 3270], y=[64], batch=[3665], ptr=[65]),
#  DataBatch(x=[3680, 3], edge_index=[2, 3284], y=[64], batch=[3680], ptr=[65]),
#  DataBatch(x=[3696, 3], edge_index=[2, 3298], y=[64], batch=[3696], ptr=[65])]

# %%
x2[0][63]
# Out:
# Data(x=[19, 3], edge_index=[2, 14], y=[0])

# %%
train_labels.shape
# Out:
# torch.Size([1, 10, 3])

# %%
train_labels[0]
# Out:
# tensor([[ 16.4350, 113.6280,  35.5000],
#         [ 16.4780, 117.1180,  35.0800],
#         [ 16.5200, 120.6000,  34.9600],
#         [ 16.5620, 124.0960,  34.9800],
#         [ 16.6050, 127.5970,  35.0000],
#         [ 16.6470, 131.0990,  34.9900],
#         [ 16.6910, 134.5950,  34.9800],
#         [ 16.7270, 138.0810,  35.1000],
#         [ 16.7960, 141.5780,  35.4900],
#         [ 16.7950, 145.1310,  36.2000]])
